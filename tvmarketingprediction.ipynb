# %% [markdown]
# <a href="https://www.kaggle.com/code/jaidasondi/tvmarketingprediction?scriptVersionId=164686309" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
#R Squared:0.7
#RMSE: 3.194
#MAE: 2.494
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.regression import linear_model 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
sales_df = pd.read_csv('/kaggle/input/tvmarketingcsv/tvmarketing.csv')

# %%
sales_df
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='TV', y='Sales', data=sales_df, s=80, color='#0B60B0')
plt.title('TV Advertising vs Sales (Initial)', color='#F0EDCF')
plt.xlabel('TV Advertising Spending', color='#F0EDCF')
plt.ylabel('Sales', color='#F0EDCF')
plt.show()

# %%
X = sales_df['TV']
y = sales_df['Sales']
X= np.array(X)
y= np.array(y)

# %%
X = X.reshape(-1,1)
y = y.reshape(-1,1)
print(X.shape)
print(y.shape)
# Out:
# (200, 1)
# (200, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %% [markdown]
# print(lr.intercept_)
# print(lr.coef_)

# %%
lr = LinearRegression() 
lr.fit(X_train, y_train)   
print(lr.intercept_)
print(lr.coef_)
# Out:
# [7.29769684]
# [[0.04750186]]

# %%
y_train.shape
# Out:
# (134, 1)

# %%
X_test.shape
# Out:
# (66, 1)

# %%
y_test.shape
# Out:
# (66, 1)

# %%
SimpleLinearRegression = LinearRegression(fit_intercept=True)
SimpleLinearRegression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('w', SimpleLinearRegression.coef_)
print('x', SimpleLinearRegression.intercept_)
# Out:
# w [[0.04750186]]
# x [7.29769684]

# %%
plt.figure(figsize=(12,6))
plt.scatter(X_train, y_train, color='#0B60B0')
plt.plot(X_train, SimpleLinearRegression.predict(X_train), color = '#40A2D8')
plt.xlabel('Sales', color='#F0EDCF')
plt.ylabel('TV', color='#F0EDCF')
plt.title('Actual VS Predicted', color='#F0EDCF')
# Out:
# Text(0.5, 1.0, 'Actual VS Predicted')

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# [7.29769684]
# [[0.04750186]]

# %%
y_pred = lr.predict(X_test)

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
y_test.shape
# Out:
# (66, 1)

# %%
plt.figure(figsize=(12, 6))
plt.scatter(range(len(y_test)), y_test, marker='o', label='Actual Values', color='#40A2D8') 
plt.scatter(range(len(y_pred)), y_pred, marker='^', label='Predicted Values', color='#0B60B0')

plt.legend()
plt.xlabel('Time Index', color='#F0EDCF')
plt.ylabel('Values', color='#F0EDCF')
plt.title('Actual vs. Predicted', color='#F0EDCF')
plt.show()

# %%
plt.figure(figsize=(12, 6))
# Calculate error terms
errors = y_test - y_pred

# Plotting error terms
plt.scatter(y_test, errors, c='#0B60B0')
plt.axhline(y=0, color='#40A2D8', linestyle='--')  
plt.xlabel('Actual Values', color='#F0EDCF')
plt.ylabel('Error Terms (Actual - Predicted)', color='#F0EDCF')
plt.title('Error Terms Analysis', color='#F0EDCF')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(y_test, y_pred, s=70, c='#0B60B0', marker='o', label='Actual')
plt.scatter(y_test, y_test, s=50, c='#40A2D8', marker='^', label='Predicted') 
plt.plot(y_test, y_test, color='gray', linewidth=2, label='Perfect Prediction')

plt.xlabel('Actual Values (Y Test)', color='#F0EDCF')
plt.ylabel('Predicted Values', color='#F0EDCF')
plt.title('Actual vs. Predicted Values', color='#F0EDCF')
plt.grid(True)
plt.legend()
plt.show()
